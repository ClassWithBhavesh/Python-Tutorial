# %% [markdown]
# # **Variables in Python**
#
# - Variable are kind of containers which will store some amount of data or values
# - for eg: if we want to name a user than we'll use a variable named "username" and value is with the actual user name
#     - username = "Samyak Jain"
#     - syntax :- variable_name = Value
# - Variable can be updated (mutable in behavior)
# - Criteria to declare a variable -
#   - the variable can be declare with the alpha numerical characters but not with the numerical alpha character
#   - the variable can be declare using only '_', except this no special character is allowed in variable declaration
#   - the variables follow the case sensitivity. matlab?
#   (jo jesa declare kiya gaya hai wese hi use karna hai)

# %%
user_name1 = "Raunak Jain"
user_name2 = "Samyak Jain"
print(user_name1)
print(user_name2)
# Out:
# Raunak Jain
# Samyak Jain
