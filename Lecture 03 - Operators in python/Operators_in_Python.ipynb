# %% [markdown]
# # **Operators in Python**
#
# - operation - is a process through which we can perform some analytical or mathematical task
# - operators - are the symbols which will be responsible to perform the operations
# - operands  - these are the values on which we perform operations
#
#
# Types of Operators in Python -
# 1. Arithmetic Operators :- +, -, /, *, //, **, %
# 2. Assignment Operators :- +=, -=, /=, *=, //=, **=, %=
# 3. Comparison Operators (Conditional Operators) :- ==, !=, >, >=, <, <=
# 4. Logical Operators :- AND | OR | NOT'
# 5. Membership Operators :- in | not in
# 6. Identity Operators :- is | is not
# 7. BitWise Operators :- AND '&' | OR '|' | XOR '^'

# %% [markdown]
# 1. Arithmetic Operators -

# %%
# num1 = 15
# num2 = 3
# # print(num1 + num2)
# result = num1 + num2
# print("addition", result)
# result = num1 - num2
# print("subtraction", result)
# result = num1 * num2
# print("product", result)
# result = num1 / num2
# print("division", result)
# result = num1 // num2
# print("floor division", result)
# result = num1 ** num2
# print("exponent", result)
# result = num1 % num2
# print("modulus (remainder)", result)
# Out:
# addition 18
# subtraction 12
# product 45
# division 5.0
# floor division 5
# exponent 3375
# modulus (remainder) 0

# %% [markdown]
# 2. Assignment Operators -

# %%
# num1 = 58
# num2 = 36
# print(num1)
# print(num2)

# num2 += num1   # num2 = num2 + num1
# num1 -= num2   # num1 = num1 - num2
# num1 /= num2   # num1 = num1 / num2
# num1 *= num2   # num1 = num1 * num2
# num1 //= num2   # num1 = num1 // num2
# num1 **= num2   # num1 = num1 ** num2
# num1 %= num2   # num1 = num1 % num2

# print(num1)
# print(num2)
# Out:
# 58
# 36
# -36
# 94

# %%
# 3. Comparison | conditional Operators -

num1 = 56
num2 = 56.2

# print(num1 != num2)
# print(num1 == num2)


if num1 == num2:
  print("Both Are Equal!")
else:
  print("Both are not Equal")

if num1 > num2:
  print("num1 is greater")
else:
  print("num2 is greater")

if num1 < num2:
  print("num2 is greater")
else:
  print("num1 is greater")

if num1 <= num2:
  print("num2 is greater or equal to num1")
else:
  print("num1 is greater or equal to num2")

if num1 >= num2:
  print("num1 is greater or equal to num2")
else:
  print("num2 is greater or equal to num1")
# Out:
# Both are not Equal
# num2 is greater
# num2 is greater
# num2 is greater or equal to num1
# num2 is greater or equal to num1

# %% [markdown]
# ### Logical Operators
# - always be used when there is more than a condition or we can say it can be operated betweem two conditional | comparison operators

# %%
# resume = True
# time = '11:00 AM'
# laptop = True

# if not resume and not time and not laptop:
#   print("Tomorrow is you interview!")
# else:
#   print("Today is you interview!")



# if resume and time == '11:00 AM' and laptop:
#   print("Today is your Interview!")
# else:
#   print("Tomorrow is your Interview!")

# if resume == True and time == '11:00 AM'and laptop == True:
#   print("Today is your Interview!")
# else:
#   print("Tomorrow is your Interview!")
# Out:
# Today is you interview!

# %% [markdown]
# ### Membership Operators -
# - in
# - not in

# %%
voters = ["MP", "UP", "J&K", "RJ"]

if "UP" in voters:
  print("UP is the member of voters")
else:
  print("UP is not a member of voters")
# Out:
# UP is the member of voters

# %%
if "GJ" not in voters:
  print("Gujrat is not a member of voters")
else:
  print("Gujrat is a member of voters")
# Out:
# Gujrat is not a member of voters

# %% [markdown]
# ### **Identity Operators**
#
# - is
# - is not

# %%
# person1 = [10,20,30,40,50]
# person2 = [10,20,30,40,50]
# person3 = person1

# # if person1 is person2:
# #   print("Both are same person")
# # else:
# #   print("Both are different person")

# if person1 is person3:
#   print("Both are same person")
# else:
#   print("Both are different person")
# Out:
# Both are same person

# %% [markdown]
# ### Bitwise Operators -
#
# - AND - &
# - OR  - |
# - XOR - ^

# %%
print(2&4)
# Out:
# 0

# %%
print(10&8)
# Out:
# 8
