# %% [markdown]
# # **Conditional Statements in Python**
#
# - Used when we have to operate or to perform a certain task on the basis of any condition.

# %% [markdown]
# 1. if Statements -

# %%
# userInput = input("Enter your feedback - ")

# when a task requires a condition to be true then goes to if statment -

# if userInput:
#   print("Thanks for your feedback!")

# when a task requires a condition with the default statement then goes to else statement -
# else:
#   print("We'll make sure to make you comfortable next time! come back soon :)").

# when a task requires multiple condition to perform certain task -


# if userInput == "Very Good":
#   print("It was", userInput)
# elif userInput == "Not Good":
#   print("It was", userInput)
# elif userInput == "Good":
#   print("It was", userInput)
# else:
#   print("Thanks for your feedback!")
# Out:
# Enter your feedback - Very Good
# It was Very Good

# %%
num1 = int(input("Enter first number - "))
num2 = int(input("Enter second number - "))
num3 = int(input("Enter third number - "))

print("Descending Order Arrangement - ")
# arange the above three variable in ascending as well as descending order
if num1 > num2 and num1 > num3:
  if num2 > num3:
    print("num1, num2, num3")
  elif num3 > num2:
    print("num1, num3, num2")
  else:
    print("num2 and num3 are equal!")
elif num2 > num1 and num2 > num3:
  if num1 > num3:
    print("num2, num1, num3")
  elif num3 > num1:
    print("num2, num3, num1")
  else:
    print("num1 and num3 are equal!")
elif num3 > num1 and num3 > num2:
  if num1 > num2:
    print("num3, num1, num2")
  elif num2 > num1:
    print("num3, num2, num1")
  else:
    print("num1 and num2 are equal!")
else:
  print("All three are equal!")
# Out:
# Enter first number - 12
# Enter second number - 258
# Enter third number - 45
# num2, num3, num1
